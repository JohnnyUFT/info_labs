# %% [markdown]
# ### Testes de buscas com Pandas Dataframe

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv', index_col='PassengerId')
titanic.head(3)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
titanic.shape
# Out:
# (891, 11)

# %%
age = titanic['Age']

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
titanic[['Name', 'Age']]
# Out:
#                                                           Name   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                                       Heikkinen, Miss. Laina  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# ...                                                        ...   ...
# 887                                      Montvila, Rev. Juozas  27.0
# 888                               Graham, Miss. Margaret Edith  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890                                      Behr, Mr. Karl Howell  26.0
# 891                                        Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
name_age = titanic[['Name', 'Age']]
type(name_age)

# %%
titanic['Age'] > 35
# Out:
# PassengerId
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Age, Length: 891, dtype: bool

# %%
titanic[titanic['Age'] > 35]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 7                   0       1
# 12                  1       1
# 14                  0       3
# 16                  1       2
# ...               ...     ...
# 866                 1       2
# 872                 1       1
# 874                 0       3
# 880                 1       1
# 886                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# ...                                                        ...     ...   ...
# ...

# %%
# df.iloc[2]
titanic.loc[12]
# Out:
# Survived                           1
# Pclass                             1
# Name        Bonnell, Miss. Elizabeth
# Sex                           female
# Age                             58.0
# SibSp                              0
# Parch                              0
# Ticket                        113783
# Fare                           26.55
# Cabin                           C103
# Embarked                           S
# Name: 12, dtype: object

# %%
titanic.loc[titanic["Age"] > 35, ["Name","Age", "Cabin"]]
# Out:
#                                                           Name   Age Cabin
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0   C85
# 7                                      McCarthy, Mr. Timothy J  54.0   E46
# 12                                    Bonnell, Miss. Elizabeth  58.0  C103
# 14                                 Andersson, Mr. Anders Johan  39.0   NaN
# 16                            Hewlett, Mrs. (Mary D Kingcome)   55.0   NaN
# ...                                                        ...   ...   ...
# 866                                   Bystrom, Mrs. (Karolina)  42.0   NaN
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0   D35
# 874                                Vander Cruyssen, Mr. Victor  47.0   NaN
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0   C50
# 886                       Rice, Mrs. William (Margaret Norton)  39.0   NaN
#
# [217 rows x 3 columns]

# %%
titanic.describe(include=object)
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
cabins = titanic[titanic["Cabin"].isin(['C', 'E'])]

# %%
titanic[(titanic["Pclass"] == 2) | (titanic["Pclass"] == 3)]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 3                   1       3                    Heikkinen, Miss. Laina
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
titanic[~titanic["Age"].notna()]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 6                   0       3                          Moran, Mr. James
# 18                  1       2              Williams, Mr. Charles Eugene
# 20                  1       3                   Masselmani, Mrs. Fatima
# 27                  0       3                   Emir, Mr. Farred Chehab
# 29                  1       3             O'Dwyer, Miss. Ellen "Nellie"
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#                 Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
titanic.iloc[0:10, 2:5]
# Out:
#                                                           Name     Sex   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %% [markdown]
# ### Replicando codigo Report Trip

# %%
ignition = True

# %%
num = int(ignition)

# %%
num
# Out:
# 1

# %%
df = titanic.query('Survived == 0')
df.head(3)
# Out:
#              Survived  Pclass                      Name   Sex   Age  SibSp  \
# PassengerId
# 1                   0       3   Braund, Mr. Owen Harris  male  22.0      1
# 5                   0       3  Allen, Mr. William Henry  male  35.0      0
# 6                   0       3          Moran, Mr. James  male   NaN      0
#
#              Parch     Ticket    Fare Cabin Embarked
# PassengerId
# 1                0  A/5 21171  7.2500   NaN        S
# 5                0     373450  8.0500   NaN        S
# 6                0     330877  8.4583   NaN        Q

# %%
df = titanic[titanic['Survived'] == 0]
df.head(3)
df.shape
# Out:
# (549, 11)

# %%
speed = 35

# %%
df = df.query('Age > @speed')
df.head(3)
df.shape
# Out:
# (134, 11)

# %% [raw]
# O problema ao tentar fazer o cast dentro da expressão da query:
# Operacao nao permitida: basta fazer o cast antes, ou utilizar o slice
# do tipo: titanic[titanic['Survived'] == int(ignition)]

# %%
# nao aceita cast dentro da expressao do query:
df = df.query('Survived == @int(ignition)')
df.head(3)
#df.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\info_lab\lib\site-packages\pandas\core\computation\scope.py:191, in Scope.resolve(self, key, is_local)
#     190 if is_local:
# --> 191     return self.scope[key]
#     193 # not a local variable so check in resolvers if we have them
#
# File ~\miniconda3\envs\info_lab\lib\collections\__init__.py:898, in ChainMap.__getitem__(self, key)
#     897         pass
# --> 898 return self.__missing__(key)
#
# File ~\miniconda3\envs\info_lab\lib\collections\__init__.py:890, in ChainMap.__missing__(self, key)
#     889 def __missing__(self, key):
# --> 890     raise KeyError(key)
#
# KeyError: 'int'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# acess more readable than pd.query()
titanic[titanic['Survived'] == int(ignition)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 876                 1       3
# 880                 1       1
# 881                 1       2
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# ...
